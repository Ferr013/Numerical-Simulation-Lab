# %% [markdown]
# # <span style="color:red"> Numerical Simulation Laboratory </span>
# ## <span style="color:brown"> ESERCIZIO 1 </span>
# ## <span style="color:blue"> es1.1 </span>

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

x, f, error = np.loadtxt("es1.1/es1_1_mean.dat", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(x,f,yerr=error)
plt.xlabel('x')
plt.ylabel('<r>')
plt.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

x, f, error = np.loadtxt("es1.1/es1_1_var.dat", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(x,f,yerr=error)
plt.xlabel('x')
plt.ylabel('<???var(r-1/2)>')
plt.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

x, f = np.loadtxt("es1.1/es1_1_chi.dat", usecols=(0,1), delimiter=' ', unpack='true')
plt.scatter(x,f)
plt.xlabel('x')
plt.ylabel('chi^2')

plt.show()

# %% [markdown]
# ## <span style="color:blue"> es1.2</span>

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

x, f = np.loadtxt("es1.2/std_N_1.dat", usecols=(0,1), delimiter=' ', unpack='true')
x1, f1 = np.loadtxt("es1.2/std_N_2.dat", usecols=(0,1), delimiter=' ', unpack='true')
x2, f2 = np.loadtxt("es1.2/std_N_10.dat", usecols=(0,1), delimiter=' ', unpack='true')
x3, f3 = np.loadtxt("es1.2/std_N_100.dat", usecols=(0,1), delimiter=' ', unpack='true')


fig, axs = plt.subplots(2, 2, figsize=(10, 10), sharex=False, sharey=False,
                        tight_layout=False)

axs[0,0].hist(f, bins=50)
axs[0,1].hist(f1, bins=50)
axs[1,0].hist(f2, bins=50)
axs[1,1].hist(f3, bins=50)
axs[0,0].set_title('Standard Dice N=1')
axs[0,1].set_title('Standard Dice N=2')
axs[1,0].set_title('Standard Dice N=10')
axs[1,1].set_title('Standard Dice N=100')


plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

x, f = np.loadtxt("es1.2/exp_N_1.dat", usecols=(0,1), delimiter=' ', unpack='true')
x1, f1 = np.loadtxt("es1.2/exp_N_2.dat", usecols=(0,1), delimiter=' ', unpack='true')
x2, f2 = np.loadtxt("es1.2/exp_N_10.dat", usecols=(0,1), delimiter=' ', unpack='true')
x3, f3 = np.loadtxt("es1.2/exp_N_100.dat", usecols=(0,1), delimiter=' ', unpack='true')


fig, axs = plt.subplots(2, 2, figsize=(10, 10), sharex=False, sharey=False,
                        tight_layout=False)

axs[0,0].hist(f, bins=50)
axs[0,1].hist(f1, bins=50)
axs[1,0].hist(f2, bins=50)
axs[1,1].hist(f3, bins=50)
axs[0,0].set_title('Exponential Dice N=1')
axs[0,1].set_title('Exponential Dice N=2')
axs[1,0].set_title('Exponential Dice N=10')
axs[1,1].set_title('Exponential Dice N=100')

plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


x, f = np.loadtxt("es1.2/lor_N_1.dat", usecols=(0,1), delimiter=' ', unpack='true')
x1, f1 = np.loadtxt("es1.2/lor_N_2.dat", usecols=(0,1), delimiter=' ', unpack='true')
x2, f2 = np.loadtxt("es1.2/lor_N_10.dat", usecols=(0,1), delimiter=' ', unpack='true')
x3, f3 = np.loadtxt("es1.2/lor_N_100.dat", usecols=(0,1), delimiter=' ', unpack='true')


fig, axs = plt.subplots(2, 2, figsize=(10, 10), sharex=False, sharey=False,
                        tight_layout=False)

axs[0,0].hist(f, bins=100, density=True)
axs[0,1].hist(f1, bins=50, density=True)
axs[1,0].hist(f2, bins=50, density=True)
axs[1,1].hist(f3, bins=50, density=True)
axs[0,0].set_title('Cauchy-Lorentz Dice N=1')
axs[0,1].set_title('Cauchy-Lorentz Dice N=2')
axs[1,0].set_title('Cauchy-Lorentz Dice N=10')
axs[1,1].set_title('Cauchy-Lorentz Dice N=100')
lim = 9
axs[0,0].set_xlim(left=-lim, right=lim)
axs[0,1].set_xlim(left=-lim, right=lim)
axs[1,0].set_xlim(left=-5000, right=5000)
axs[1,1].set_xlim(left=-lim, right=lim)

plt.show()

# %% [markdown]
# ## <span style="color:blue"> es1.3</span>

# %% [markdown]
# Testato anche cercando una distribuzione seno (ma richiedeva di utilizzare pi greco), e con angolo=arctan(Rannyu()/Rannyu()) ma dava problemi di compattezza per angoli -> pi/2

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

x, f, error = np.loadtxt("es1.3/es1_3.dat", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(x,f,yerr=error,label='Calculated $\pi$')
plt.xlabel('# throws')
plt.ylabel(r'$\pi$')
plt.axhline(y=3.1415926535, xmin=0, xmax=1, color='orange', label='True $\pi$')
legend = plt.legend(loc='lower right', shadow=True, fontsize='x-large')
plt.grid(True)
plt.show()
